# %%
# Install required libraries
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (4.42.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy<2.0,>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.5.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2024.7.4)

# %%
# Define path to data
cha_path = '/kaggle/input/PittCombined8class/cha'

# %%
# Import necessary libraries
import os
import pandas as pd
from transformers import BertTokenizer, BertModel

# %%
# List files in directory
cha_files = [os.path.join(cha_path, file) for file in os.listdir(cha_path) if file.endswith('.cha')]
print(f"Found {len(cha_files)} CHA files.")
# Out:
# Found 1254 CHA files.

# %%
import re
import random
from collections import defaultdict, Counter

# %%
def extract_diagnosis(cha_file):
    """Extracts the diagnosis from a CHAT transcript file."""
    with open(cha_file, 'r') as file:
        content = file.read()
    match = re.search(r'@ID:\s*[^|]*\|[^|]*\|[^|]*\|[^|]*\|[^|]*\|([^|]*)\|', content)
    return match.group(1) if match else None

# %%
# Load all CHA files and their diagnoses
diagnoses = [extract_diagnosis(f) for f in cha_files]

# %%
# Group files by diagnosis
files_by_diagnosis = defaultdict(list)
for cha_file, diag in zip(cha_files, diagnoses):
    files_by_diagnosis[diag].append(cha_file)

# %%
# Select up to 500 files, trying to balance across diagnoses
selected_files = []
for diag, files in files_by_diagnosis.items():
    if len(files) >= 10:
        selected_files.extend(random.sample(files, min(len(files), max(500 // len(files_by_diagnosis), 10))))
selected_files = random.sample(selected_files, min(500, len(selected_files)))

# %%
selected_diagnoses = [extract_diagnosis(f) for f in selected_files]
diagnosis_count = Counter(selected_diagnoses)
print("Diagnosis counts:", dict(diagnosis_count))
# Out:
# Diagnosis counts: {'MCI': 62, 'ProbableAD': 62, 'Memory': 12, 'Control': 62, 'Vascular': 19, 'PossibleAD': 62}

# %%
from transformers import BertTokenizer, BertModel

# Initialize Clinical BERT
tokenizer = BertTokenizer.from_pretrained("emilyalsentzer/Bio_ClinicalBERT")
model = BertModel.from_pretrained("emilyalsentzer/Bio_ClinicalBERT")
# Out:
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/436M [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()

# %%
def preprocess_text(file_path):
    """Extracts text embeddings from a file using BioBERT."""
    with open(file_path, 'r') as file:
        text = file.read()
    inputs = tokenizer(text, return_tensors="pt", max_length=512, truncation=True, padding="max_length")
    outputs = model(**inputs)
    return outputs.last_hidden_state.squeeze().mean(dim=0).detach().numpy()

# %%
# Process each file
text_embeddings = [preprocess_text(f) for f in selected_files]

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# Convert list to numpy arrays
text_features = np.array(text_embeddings)

# %%
# Normalize the features
scaler = StandardScaler()
normalized_features = scaler.fit_transform(text_features)

# %%
from sklearn.preprocessing import LabelEncoder

# Encode labels as integers
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(selected_diagnoses)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
# Out:
# 2024-08-22 00:25:43.891209: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-22 00:25:43.891444: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-22 00:25:44.042409: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Split data into train, validation, and test sets
X_train, X_test, y_train, y_test = train_test_split(normalized_features, encoded_labels, test_size=0.2, random_state=42, stratify=encoded_labels)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=42)

# %%
num_classes = len(np.unique(encoded_labels))

from tensorflow.keras.regularizers import l2

# Model architecture
input_layer = Input(shape=(768,))  # Adjust input shape to match the output of BioBERT
dense_layer = Dense(128, activation='relu',kernel_regularizer=l2(0.1))(input_layer)
batch_norm_layer = BatchNormalization()(dense_layer)
dropout_layer = Dropout(0.5)(batch_norm_layer)
output_layer = Dense(num_classes, activation='softmax')(dropout_layer)
model = Model(inputs=input_layer, outputs=output_layer)

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy', 'Precision', 'Recall'])

# %%
# Fit model on training data
history = model.fit(X_train, to_categorical(y_train, num_classes=num_classes), validation_data=(X_val, to_categorical(y_val, num_classes=num_classes)), epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - Precision: 0.0928 - Recall: 0.0523 - accuracy: 0.1150 - loss: 25.0963 - val_Precision: 0.4118 - val_Recall: 0.2500 - val_accuracy: 0.3036 - val_loss: 22.2064
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.4240 - Recall: 0.2910 - accuracy: 0.3829 - loss: 21.9900 - val_Precision: 0.4359 - val_Recall: 0.3036 - val_accuracy: 0.3393 - val_loss: 20.5114
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.5487 - Recall: 0.3840 - accuracy: 0.5276 - loss: 19.7400 - val_Precision: 0.4500 - val_Recall: 0.3214 - val_accuracy: 0.4464 - val_loss: 18.6862
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - Precision: 0.5046 - Recall: 0.3520 - accuracy: 0.4459 - loss: 18.2013 - val_Precision: 0.4878 - val_Recall: 0.3571 - val_accuracy: 0.4821 - val_loss: 17.1082
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.6035 - Recall: 0.4453 - accuracy: 0.5288 - loss: 16.4537 - val_Precision: 0.4857 - val_Recall: 0.3036 - val_accuracy: 0.4643 - val_loss: 15.6291
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - Precision: 0.6577 - Recall: 0.4255 - accuracy: 0.5723 - loss: 14.8579 - val_Precision: 0.3871 - val_Recall: 0.2143 - val_accuracy: 0.3750 - val_loss: 14.3410
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.6388 - Recall: 0.4204 - accuracy: 0.5272 - loss: 13.5435 - val_Precision: 0.4231 - val_Recall: 0.1964 - val_accuracy: 0.3571 - val_loss: 13.1969
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.7229 - Recall: 0.5128 - accuracy: 0.6333 - loss: 12.3481 - val_Precision: 0.3939 - val_Recall: 0.2321 - val_accuracy: 0.3571 - val_loss: 12.1410
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.6904 - Recall: 0.5468 - accuracy: 0.6357 - loss: 11.3166 - val_Precision: 0.3571 - val_Recall: 0.1786 - val_accuracy: 0.3571 - val_loss: 11.1146
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.7722 - Recall: 0.5877 - accuracy: 0.7116 - loss: 10.2094 - val_Precision: 0.3600 - val_Recall: 0.1607 - val_accuracy: 0.3571 - val_loss: 10.2341
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.7567 - Recall: 0.6149 - accuracy: 0.7073 - loss: 9.3468 - val_Precision: 0.3571 - val_Recall: 0.1786 - val_accuracy: 0.3393 - val_loss: 9.4776
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.7453 - Recall: 0.6032 - accuracy: 0.6720 - loss: 8.5816 - val_Precision: 0.3214 - val_Recall: 0.1607 - val_accuracy: 0.4107 - val_loss: 8.8201
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.7931 - Recall: 0.6696 - accuracy: 0.7503 - loss: 7.8196 - val_Precision: 0.3929 - val_Recall: 0.1964 - val_accuracy: 0.4286 - val_loss: 8.2275
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8277 - Recall: 0.6571 - accuracy: 0.7445 - loss: 7.2507 - val_Precision: 0.3793 - val_Recall: 0.1964 - val_accuracy: 0.3929 - val_loss: 7.6511
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8309 - Recall: 0.6346 - accuracy: 0.7441 - loss: 6.6199 - val_Precision: 0.4074 - val_Recall: 0.1964 - val_accuracy: 0.4107 - val_loss: 7.2309
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8079 - Recall: 0.7110 - accuracy: 0.8108 - loss: 6.1559 - val_Precision: 0.3929 - val_Recall: 0.1964 - val_accuracy: 0.3571 - val_loss: 6.7903
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8629 - Recall: 0.7645 - accuracy: 0.7959 - loss: 5.6047 - val_Precision: 0.4242 - val_Recall: 0.2500 - val_accuracy: 0.4286 - val_loss: 6.3442
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - Precision: 0.8817 - Recall: 0.7925 - accuracy: 0.8429 - loss: 5.2089 - val_Precision: 0.4516 - val_Recall: 0.2500 - val_accuracy: 0.4286 - val_loss: 5.9300
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8792 - Recall: 0.7751 - accuracy: 0.8382 - loss: 4.8721 - val_Precision: 0.4333 - val_Recall: 0.2321 - val_accuracy: 0.4286 - val_loss: 5.6644
# Epoch 20/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.7916 - Recall: 0.7366 - accuracy: 0.7634 - loss: 4.6804 - val_Precision: 0.4333 - val_Recall: 0.2321 - val_accuracy: 0.3929 - val_loss: 5.3356
# Epoch 21/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8350 - Recall: 0.7650 - accuracy: 0.8052 - loss: 4.2141 - val_Precision: 0.4074 - val_Recall: 0.1964 - val_accuracy: 0.3750 - val_loss: 5.0530
# Epoch 22/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8591 - Recall: 0.7187 - accuracy: 0.8242 - loss: 3.9672 - val_Precision: 0.4000 - val_Recall: 0.2143 - val_accuracy: 0.4107 - val_loss: 4.7902
# Epoch 23/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - Precision: 0.8133 - Recall: 0.7424 - accuracy: 0.8019 - loss: 3.7453 - val_Precision: 0.4231 - val_Recall: 0.1964 - val_accuracy: 0.4107 - val_loss: 4.5587
# Epoch 24/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - Precision: 0.8536 - Recall: 0.7379 - accuracy: 0.8208 - loss: 3.5164 - val_Precision: 0.3929 - val_Recall: 0.1964 - val_accuracy: 0.3929 - val_loss: 4.3355
# Epoch 25/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8654 - Recall: 0.7354 - accuracy: 0.8232 - loss: 3.2728 - val_Precision: 0.4074 - val_Recall: 0.1964 - val_accuracy: 0.4286 - val_loss: 4.1622
# Epoch 26/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8942 - Recall: 0.7918 - accuracy: 0.8454 - loss: 2.9776 - val_Precision: 0.4242 - val_Recall: 0.2500 - val_accuracy: 0.3929 - val_loss: 4.0014
# Epoch 27/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.9260 - Recall: 0.8267 - accuracy: 0.8535 - loss: 2.7669 - val_Precision: 0.4211 - val_Recall: 0.2857 - val_accuracy: 0.3750 - val_loss: 3.9414
# Epoch 28/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8597 - Recall: 0.7738 - accuracy: 0.8220 - loss: 2.7263 - val_Precision: 0.5128 - val_Recall: 0.3571 - val_accuracy: 0.4464 - val_loss: 3.8273
# Epoch 29/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8838 - Recall: 0.7524 - accuracy: 0.8316 - loss: 2.5750 - val_Precision: 0.4444 - val_Recall: 0.2857 - val_accuracy: 0.4286 - val_loss: 3.6329
# Epoch 30/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - Precision: 0.9212 - Recall: 0.7788 - accuracy: 0.8646 - loss: 2.4334 - val_Precision: 0.4412 - val_Recall: 0.2679 - val_accuracy: 0.4107 - val_loss: 3.5157
# Epoch 31/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - Precision: 0.8619 - Recall: 0.7672 - accuracy: 0.7938 - loss: 2.4112 - val_Precision: 0.4865 - val_Recall: 0.3214 - val_accuracy: 0.4286 - val_loss: 3.4673
# Epoch 32/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8658 - Recall: 0.7987 - accuracy: 0.8444 - loss: 2.2262 - val_Precision: 0.4118 - val_Recall: 0.2500 - val_accuracy: 0.3571 - val_loss: 3.4162
# Epoch 33/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.9195 - Recall: 0.7915 - accuracy: 0.8365 - loss: 2.1693 - val_Precision: 0.4054 - val_Recall: 0.2679 - val_accuracy: 0.4107 - val_loss: 3.3706
# Epoch 34/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8732 - Recall: 0.7017 - accuracy: 0.7938 - loss: 2.1167 - val_Precision: 0.4375 - val_Recall: 0.2500 - val_accuracy: 0.3571 - val_loss: 3.3192
# Epoch 35/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.9041 - Recall: 0.7703 - accuracy: 0.8357 - loss: 1.9876 - val_Precision: 0.4062 - val_Recall: 0.2321 - val_accuracy: 0.3929 - val_loss: 3.1284
# Epoch 36/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8893 - Recall: 0.7871 - accuracy: 0.8304 - loss: 2.0056 - val_Precision: 0.4074 - val_Recall: 0.1964 - val_accuracy: 0.3929 - val_loss: 3.0500
# Epoch 37/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - Precision: 0.8727 - Recall: 0.7589 - accuracy: 0.8141 - loss: 1.9687 - val_Precision: 0.5000 - val_Recall: 0.2321 - val_accuracy: 0.4107 - val_loss: 3.0128
# Epoch 38/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8277 - Recall: 0.7488 - accuracy: 0.7931 - loss: 2.0674 - val_Precision: 0.4333 - val_Recall: 0.2321 - val_accuracy: 0.3929 - val_loss: 3.0929
# Epoch 39/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8763 - Recall: 0.7944 - accuracy: 0.8468 - loss: 1.7627 - val_Precision: 0.3250 - val_Recall: 0.2321 - val_accuracy: 0.3393 - val_loss: 3.2228
# Epoch 40/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8398 - Recall: 0.7798 - accuracy: 0.8144 - loss: 1.8207 - val_Precision: 0.3514 - val_Recall: 0.2321 - val_accuracy: 0.4464 - val_loss: 3.0741
# Epoch 41/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8851 - Recall: 0.7778 - accuracy: 0.8503 - loss: 1.7010 - val_Precision: 0.3947 - val_Recall: 0.2679 - val_accuracy: 0.3929 - val_loss: 3.0259
# Epoch 42/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - Precision: 0.9228 - Recall: 0.8133 - accuracy: 0.8867 - loss: 1.5636 - val_Precision: 0.3846 - val_Recall: 0.2679 - val_accuracy: 0.3929 - val_loss: 3.0000
# Epoch 43/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - Precision: 0.8761 - Recall: 0.7688 - accuracy: 0.8261 - loss: 1.6890 - val_Precision: 0.3902 - val_Recall: 0.2857 - val_accuracy: 0.3750 - val_loss: 3.0156
# Epoch 44/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - Precision: 0.8121 - Recall: 0.7401 - accuracy: 0.7580 - loss: 1.7273 - val_Precision: 0.4865 - val_Recall: 0.3214 - val_accuracy: 0.4286 - val_loss: 3.0051
# Epoch 45/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - Precision: 0.8315 - Recall: 0.7500 - accuracy: 0.7894 - loss: 1.6377 - val_Precision: 0.4615 - val_Recall: 0.2143 - val_accuracy: 0.3036 - val_loss: 2.9047
# Epoch 46/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8867 - Recall: 0.7879 - accuracy: 0.8541 - loss: 1.4847 - val_Precision: 0.4545 - val_Recall: 0.2679 - val_accuracy: 0.3750 - val_loss: 2.8612
# Epoch 47/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8614 - Recall: 0.8132 - accuracy: 0.8537 - loss: 1.4375 - val_Precision: 0.3902 - val_Recall: 0.2857 - val_accuracy: 0.3750 - val_loss: 3.0387
# Epoch 48/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8795 - Recall: 0.7888 - accuracy: 0.8397 - loss: 1.4489 - val_Precision: 0.3611 - val_Recall: 0.2321 - val_accuracy: 0.3036 - val_loss: 2.9147
# Epoch 49/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8619 - Recall: 0.7830 - accuracy: 0.8079 - loss: 1.4468 - val_Precision: 0.3191 - val_Recall: 0.2679 - val_accuracy: 0.3036 - val_loss: 2.9774
# Epoch 50/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8121 - Recall: 0.7400 - accuracy: 0.7746 - loss: 1.4945 - val_Precision: 0.3696 - val_Recall: 0.3036 - val_accuracy: 0.3214 - val_loss: 2.9416
# Epoch 51/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8617 - Recall: 0.7578 - accuracy: 0.7976 - loss: 1.4669 - val_Precision: 0.3333 - val_Recall: 0.2143 - val_accuracy: 0.3036 - val_loss: 2.9970
# Epoch 52/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8234 - Recall: 0.7397 - accuracy: 0.8051 - loss: 1.5196 - val_Precision: 0.3077 - val_Recall: 0.2143 - val_accuracy: 0.2679 - val_loss: 2.9816
# Epoch 53/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8633 - Recall: 0.8075 - accuracy: 0.8555 - loss: 1.3536 - val_Precision: 0.2727 - val_Recall: 0.2143 - val_accuracy: 0.2679 - val_loss: 3.0533
# Epoch 54/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.7953 - Recall: 0.7097 - accuracy: 0.7635 - loss: 1.5299 - val_Precision: 0.2500 - val_Recall: 0.1964 - val_accuracy: 0.2857 - val_loss: 3.1231
# Epoch 55/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8599 - Recall: 0.7383 - accuracy: 0.7875 - loss: 1.4532 - val_Precision: 0.3077 - val_Recall: 0.2143 - val_accuracy: 0.3393 - val_loss: 2.9190
# Epoch 56/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8936 - Recall: 0.7974 - accuracy: 0.8502 - loss: 1.4725 - val_Precision: 0.4146 - val_Recall: 0.3036 - val_accuracy: 0.3571 - val_loss: 2.8504
# Epoch 57/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8417 - Recall: 0.7325 - accuracy: 0.7846 - loss: 1.4950 - val_Precision: 0.4615 - val_Recall: 0.3214 - val_accuracy: 0.3929 - val_loss: 2.8949
# Epoch 58/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.9406 - Recall: 0.8302 - accuracy: 0.8674 - loss: 1.3154 - val_Precision: 0.4286 - val_Recall: 0.3214 - val_accuracy: 0.3929 - val_loss: 2.9011
# Epoch 59/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - Precision: 0.8476 - Recall: 0.7767 - accuracy: 0.8264 - loss: 1.3615 - val_Precision: 0.4474 - val_Recall: 0.3036 - val_accuracy: 0.3571 - val_loss: 2.8558
# Epoch 60/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8485 - Recall: 0.7677 - accuracy: 0.8145 - loss: 1.4050 - val_Precision: 0.5000 - val_Recall: 0.3571 - val_accuracy: 0.4107 - val_loss: 2.8107
# Epoch 61/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8358 - Recall: 0.7523 - accuracy: 0.8036 - loss: 1.3285 - val_Precision: 0.4390 - val_Recall: 0.3214 - val_accuracy: 0.3929 - val_loss: 2.7179
# Epoch 62/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - Precision: 0.8109 - Recall: 0.7351 - accuracy: 0.7787 - loss: 1.3306 - val_Precision: 0.4091 - val_Recall: 0.3214 - val_accuracy: 0.4107 - val_loss: 2.6609
# Epoch 63/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.9163 - Recall: 0.8547 - accuracy: 0.8964 - loss: 1.1127 - val_Precision: 0.3571 - val_Recall: 0.2679 - val_accuracy: 0.3571 - val_loss: 2.7990
# Epoch 64/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8718 - Recall: 0.7552 - accuracy: 0.8095 - loss: 1.2219 - val_Precision: 0.4390 - val_Recall: 0.3214 - val_accuracy: 0.4643 - val_loss: 2.6814
# Epoch 65/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - Precision: 0.8903 - Recall: 0.8179 - accuracy: 0.8580 - loss: 1.1208 - val_Precision: 0.4048 - val_Recall: 0.3036 - val_accuracy: 0.4286 - val_loss: 2.5898
# Epoch 66/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8733 - Recall: 0.8045 - accuracy: 0.8691 - loss: 1.1155 - val_Precision: 0.4419 - val_Recall: 0.3393 - val_accuracy: 0.4107 - val_loss: 2.6622
# Epoch 67/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8618 - Recall: 0.7984 - accuracy: 0.8479 - loss: 1.2383 - val_Precision: 0.4043 - val_Recall: 0.3393 - val_accuracy: 0.4107 - val_loss: 2.6725
# Epoch 68/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8677 - Recall: 0.7909 - accuracy: 0.8479 - loss: 1.1179 - val_Precision: 0.4082 - val_Recall: 0.3571 - val_accuracy: 0.4286 - val_loss: 2.6710
# Epoch 69/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - Precision: 0.8749 - Recall: 0.7857 - accuracy: 0.8247 - loss: 1.1250 - val_Precision: 0.4091 - val_Recall: 0.3214 - val_accuracy: 0.3929 - val_loss: 2.6368
# Epoch 70/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - Precision: 0.9545 - Recall: 0.8566 - accuracy: 0.9068 - loss: 0.9671 - val_Precision: 0.4286 - val_Recall: 0.3214 - val_accuracy: 0.3571 - val_loss: 2.5992
# Epoch 71/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8681 - Recall: 0.8252 - accuracy: 0.8401 - loss: 1.1148 - val_Precision: 0.4651 - val_Recall: 0.3571 - val_accuracy: 0.4107 - val_loss: 2.6875
# Epoch 72/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8444 - Recall: 0.8144 - accuracy: 0.8326 - loss: 1.1181 - val_Precision: 0.3556 - val_Recall: 0.2857 - val_accuracy: 0.3214 - val_loss: 2.8616
# Epoch 73/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8870 - Recall: 0.7903 - accuracy: 0.8484 - loss: 1.1098 - val_Precision: 0.3721 - val_Recall: 0.2857 - val_accuracy: 0.3571 - val_loss: 3.0457
# Epoch 74/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8515 - Recall: 0.7546 - accuracy: 0.8056 - loss: 1.2111 - val_Precision: 0.4091 - val_Recall: 0.3214 - val_accuracy: 0.3750 - val_loss: 2.9833
# Epoch 75/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.9004 - Recall: 0.8093 - accuracy: 0.8554 - loss: 1.1231 - val_Precision: 0.4565 - val_Recall: 0.3750 - val_accuracy: 0.4286 - val_loss: 2.7261
# Epoch 76/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8112 - Recall: 0.7405 - accuracy: 0.7969 - loss: 1.2930 - val_Precision: 0.4186 - val_Recall: 0.3214 - val_accuracy: 0.4107 - val_loss: 2.7178
# Epoch 77/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.9037 - Recall: 0.8037 - accuracy: 0.8353 - loss: 1.1794 - val_Precision: 0.4250 - val_Recall: 0.3036 - val_accuracy: 0.3750 - val_loss: 2.8435
# Epoch 78/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.7956 - Recall: 0.6498 - accuracy: 0.7372 - loss: 1.4791 - val_Precision: 0.4167 - val_Recall: 0.2679 - val_accuracy: 0.3929 - val_loss: 2.8175
# Epoch 79/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8113 - Recall: 0.6740 - accuracy: 0.7471 - loss: 1.5408 - val_Precision: 0.4773 - val_Recall: 0.3750 - val_accuracy: 0.4107 - val_loss: 2.9021
# Epoch 80/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8177 - Recall: 0.7296 - accuracy: 0.7776 - loss: 1.3661 - val_Precision: 0.4651 - val_Recall: 0.3571 - val_accuracy: 0.4107 - val_loss: 2.8041
# Epoch 81/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.7741 - Recall: 0.6476 - accuracy: 0.7025 - loss: 1.5476 - val_Precision: 0.4000 - val_Recall: 0.2857 - val_accuracy: 0.3750 - val_loss: 2.8477
# Epoch 82/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8391 - Recall: 0.7698 - accuracy: 0.8029 - loss: 1.3365 - val_Precision: 0.3556 - val_Recall: 0.2857 - val_accuracy: 0.3571 - val_loss: 2.7769
# Epoch 83/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8931 - Recall: 0.8090 - accuracy: 0.8656 - loss: 1.2245 - val_Precision: 0.3830 - val_Recall: 0.3214 - val_accuracy: 0.3750 - val_loss: 2.7133
# Epoch 84/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.7900 - Recall: 0.6973 - accuracy: 0.7511 - loss: 1.4615 - val_Precision: 0.4324 - val_Recall: 0.2857 - val_accuracy: 0.3750 - val_loss: 2.7113
# Epoch 85/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8761 - Recall: 0.7468 - accuracy: 0.7921 - loss: 1.2382 - val_Precision: 0.4878 - val_Recall: 0.3571 - val_accuracy: 0.4464 - val_loss: 2.6748
# Epoch 86/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8457 - Recall: 0.7218 - accuracy: 0.7996 - loss: 1.3087 - val_Precision: 0.4419 - val_Recall: 0.3393 - val_accuracy: 0.4286 - val_loss: 2.5881
# Epoch 87/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8653 - Recall: 0.7966 - accuracy: 0.8360 - loss: 1.1973 - val_Precision: 0.4419 - val_Recall: 0.3393 - val_accuracy: 0.3929 - val_loss: 2.5587
# Epoch 88/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.9113 - Recall: 0.8261 - accuracy: 0.8764 - loss: 1.1586 - val_Precision: 0.4211 - val_Recall: 0.2857 - val_accuracy: 0.4107 - val_loss: 2.4976
# Epoch 89/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8604 - Recall: 0.7894 - accuracy: 0.8041 - loss: 1.2571 - val_Precision: 0.4848 - val_Recall: 0.2857 - val_accuracy: 0.4286 - val_loss: 2.3740
# Epoch 90/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.9027 - Recall: 0.8029 - accuracy: 0.8826 - loss: 1.1158 - val_Precision: 0.4722 - val_Recall: 0.3036 - val_accuracy: 0.3571 - val_loss: 2.4302
# Epoch 91/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8828 - Recall: 0.8255 - accuracy: 0.8556 - loss: 1.0860 - val_Precision: 0.4359 - val_Recall: 0.3036 - val_accuracy: 0.3929 - val_loss: 2.5532
# Epoch 92/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8401 - Recall: 0.7953 - accuracy: 0.8198 - loss: 1.1665 - val_Precision: 0.4103 - val_Recall: 0.2857 - val_accuracy: 0.4107 - val_loss: 2.6792
# Epoch 93/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8752 - Recall: 0.7539 - accuracy: 0.8238 - loss: 1.1044 - val_Precision: 0.4615 - val_Recall: 0.3214 - val_accuracy: 0.3929 - val_loss: 2.7858
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8443 - Recall: 0.7506 - accuracy: 0.8142 - loss: 1.2454 - val_Precision: 0.4146 - val_Recall: 0.3036 - val_accuracy: 0.4464 - val_loss: 2.5640
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - Precision: 0.8635 - Recall: 0.8048 - accuracy: 0.8211 - loss: 1.1650 - val_Precision: 0.4146 - val_Recall: 0.3036 - val_accuracy: 0.4107 - val_loss: 2.6091
# Epoch 96/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.9162 - Recall: 0.8108 - accuracy: 0.8822 - loss: 1.1075 - val_Precision: 0.3721 - val_Recall: 0.2857 - val_accuracy: 0.3393 - val_loss: 2.7358
# Epoch 97/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8668 - Recall: 0.7906 - accuracy: 0.8293 - loss: 1.0928 - val_Precision: 0.2667 - val_Recall: 0.2143 - val_accuracy: 0.2857 - val_loss: 2.7962
# Epoch 98/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8749 - Recall: 0.8283 - accuracy: 0.8610 - loss: 1.1510 - val_Precision: 0.3043 - val_Recall: 0.2500 - val_accuracy: 0.2857 - val_loss: 2.9173
# Epoch 99/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8756 - Recall: 0.8140 - accuracy: 0.8415 - loss: 1.1253 - val_Precision: 0.4762 - val_Recall: 0.3571 - val_accuracy: 0.3929 - val_loss: 2.7037
# Epoch 100/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - Precision: 0.8802 - Recall: 0.8275 - accuracy: 0.8714 - loss: 1.1126 - val_Precision: 0.4286 - val_Recall: 0.3214 - val_accuracy: 0.4107 - val_loss: 2.6721

# %%
# Evaluate the model
evaluation = model.evaluate(X_test, to_categorical(y_test, num_classes=num_classes))
print(f'Accuracy: {evaluation[1]*100:.2f}%, Precision: {evaluation[2]*100:.2f}%, Recall: {evaluation[3]*100:.2f}%')
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - Precision: 0.4881 - Recall: 0.4092 - accuracy: 0.4896 - loss: 2.7723
# Accuracy: 50.00%, Precision: 50.00%, Recall: 41.07%

# %%
from sklearn.metrics import classification_report

# Predict classes on the test set
predictions = model.predict(X_test)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(to_categorical(y_test, num_classes=num_classes), axis=1)

# Calculate per-class accuracy, precision, and recall
report = classification_report(true_classes, predicted_classes, target_names=label_encoder.classes_)
print(report)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#               precision    recall  f1-score   support
#
#      Control       0.65      0.85      0.73        13
#          MCI       0.40      0.33      0.36        12
#       Memory       0.00      0.00      0.00         2
#   PossibleAD       0.45      0.69      0.55        13
#   ProbableAD       0.57      0.33      0.42        12
#     Vascular       0.00      0.00      0.00         4
#
#     accuracy                           0.50        56
#    macro avg       0.34      0.37      0.34        56
# weighted avg       0.46      0.50      0.47        56

# %%
import matplotlib.pyplot as plt

# Assuming 'history' is the variable that stores the history returned by the model.fit() method
def plot_training_history(history):
    # Plotting accuracy
    plt.figure(figsize=(12, 8))

    # Accuracy
    plt.subplot(2, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    # Loss
    plt.subplot(2, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    # Precision
    plt.subplot(2, 2, 3)
    plt.plot(history.history['Precision'], label='Training Precision')
    plt.plot(history.history['val_Precision'], label='Validation Precision')
    plt.title('Model Precision')
    plt.xlabel('Epoch')
    plt.ylabel('Precision')
    plt.legend()

    # Recall
    plt.subplot(2, 2, 4)
    plt.plot(history.history['Recall'], label='Training Recall')
    plt.plot(history.history['val_Recall'], label='Validation Recall')
    plt.title('Model Recall')
    plt.xlabel('Epoch')
    plt.ylabel('Recall')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Example usage:
# Assuming you have trained the model with:
# history = model.fit(...)
# Call the function to plot
plot_training_history(history)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Assuming 'y_test' are the true labels and 'predicted_classes' are the predicted labels
def plot_confusion_matrix(y_test, predicted_classes, class_names):
    cm = confusion_matrix(y_test, predicted_classes)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

# Example usage:
class_names = label_encoder.classes_  # Assuming you have a label encoder used for your classes
plot_confusion_matrix(true_classes, predicted_classes, class_names)

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_auc_score

# Binarize the labels for multi-class ROC curve
y_test_binarized = label_binarize(y_test, classes=np.arange(num_classes))

def plot_roc_curves(y_test_binarized, predictions, num_classes):
    fpr = dict()
    tpr = dict()
    roc_auc = dict()

    plt.figure(figsize=(14, 10))
    
    for i in range(num_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test_binarized[:, i], predictions[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
        plt.plot(fpr[i], tpr[i], lw=2, label=f'Class {i} (area = {roc_auc[i]:.2f})')

    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve for Multi-Class')
    plt.legend(loc="lower right")
    plt.show()

# Example usage:
plot_roc_curves(y_test_binarized, predictions, num_classes)

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score

def plot_precision_recall_curves(y_test_binarized, predictions, num_classes):
    plt.figure(figsize=(14, 10))
    
    for i in range(num_classes):
        precision, recall, _ = precision_recall_curve(y_test_binarized[:, i], predictions[:, i])
        average_precision = average_precision_score(y_test_binarized[:, i], predictions[:, i])
        plt.plot(recall, precision, lw=2, label=f'Class {i} (AP = {average_precision:.2f})')

    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall Curve for Multi-Class')
    plt.legend(loc="lower left")
    plt.show()

# Example usage:
plot_precision_recall_curves(y_test_binarized, predictions, num_classes)
